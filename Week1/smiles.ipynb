# %%
import kagglehub
path = kagglehub.dataset_download("datatattle/covid-19-nlp-text-classification")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/covid-19-nlp-text-classification

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(path + "/Corona_NLP_train.csv",encoding='latin-1')
df.head()
# Out:
#    UserName  ScreenName   Location     TweetAt  \
# 0      3799       48751     London  16-03-2020
# 1      3800       48752         UK  16-03-2020
# 2      3801       48753  Vagabonds  16-03-2020
# 3      3802       48754        NaN  16-03-2020
# 4      3803       48755        NaN  16-03-2020
#
#                                        OriginalTweet           Sentiment
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...             Neutral
# 1  advice Talk to your neighbours family to excha...            Positive
# 2  Coronavirus Australia: Woolworths to give elde...            Positive
# 3  My food stock is not the only one which is emp...            Positive
# 4  Me, ready to go at supermarket during the #COV...  Extremely Negative

# %%
#Removing duplicates after checking
if(list(df.duplicated().value_counts())[0]):
  df.drop_duplicates(inplace=True)
#removing rows with missing values
df.dropna(inplace=True)

# %%
#making function to remove stop words
import nltk
nltk.download('stopwords')
nltk.download('punkt_tab')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
  word_tokens = word_tokenize(text)
  filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
  return filtered_sentence
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
#applying the function to the dataframe
df['OriginalTweet']=df['OriginalTweet'].apply(remove_stopwords)
df.head()
# Out:
#    UserName  ScreenName   Location     TweetAt  \
# 0      3799       48751     London  16-03-2020
# 1      3800       48752         UK  16-03-2020
# 2      3801       48753  Vagabonds  16-03-2020
# 3      3802       48754        NaN  16-03-2020
# 4      3803       48755        NaN  16-03-2020
#
#                                        OriginalTweet           Sentiment
# 0  [@, MeNyrbie, @, Phil_Gahan, @, Chrisitv, http...             Neutral
# 1  [advice, Talk, neighbours, family, exchange, p...            Positive
# 2  [Coronavirus, Australia, :, Woolworths, give, ...            Positive
# 3  [food, stock, one, empty, ..., PLEASE, ,, n't,...            Positive
# 4  [,, ready, go, supermarket, #, COVID19, outbre...  Extremely Negative
