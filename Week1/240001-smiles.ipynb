# %%
import kagglehub
path = kagglehub.dataset_download('tanishqdublish/text-classification-documentation')
print(path)
# Out:
# /kaggle/input/text-classification-documentation

# %%
import pandas as pd
df = pd.read_csv(path + '/df_file.csv')
df.head()
# Out:
#                                                 Text  Label
# 0  Budget to set scene for election\n \n Gordon B...      0
# 1  Army chiefs in regiments decision\n \n Militar...      0
# 2  Howard denies split over ID cards\n \n Michael...      0
# 3  Observers to monitor UK election\n \n Minister...      0
# 4  Kilroy names election seat target\n \n Ex-chat...      0

# %%
print(df.duplicated().value_counts())
df.drop_duplicates(inplace=True)
# Out:
# False    2127
# Name: count, dtype: int64

# %%
df.dropna(inplace=True)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt_tab')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))

def filter_stopwords(text):
    tokens = word_tokenize(text)
    filtered = [word for word in tokens if not word.lower() in stop_words]
    return filtered
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno -3]
# [nltk_data]     Temporary failure in name resolution>
# [nltk_data] Error loading punkt_tab: <urlopen error [Errno -3]
# [nltk_data]     Temporary failure in name resolution>

# %%
df['Text'] = df['Text'].apply(filter_stopwords)
df.head()
# Out:
#                                                 Text  Label
# 0  [Budget, set, scene, election, Gordon, Brown, ...      0
# 1  [Army, chiefs, regiments, decision, Military, ...      0
# 2  [Howard, denies, split, ID, cards, Michael, Ho...      0
# 3  [Observers, monitor, UK, election, Ministers, ...      0
# 4  [Kilroy, names, election, seat, target, Ex-cha...      0
